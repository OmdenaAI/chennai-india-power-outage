# %% [markdown]
# # About
# - **By**: Tsombou Christian
# - **@** : tsombouchris@gmail.com
# - **linkedIn**: https://www.linkedin.com/in/tsombouchris/
#
# This Notebook performs an Scrapping of POSOCO website in order to obtain on Demand and Supply of Energy in Tamil Nadu in India from PDF periodical reports on the period July 2014 to May 2022
#
# - **Data Source**: [POSOCO website](https://posoco.in/reports/monthly-reports/)
# - **Data unit**: Demand and Supply of Energy is in MU - Million Unit (unit of energy) or in MW Mega-Watt
# - **Reference**: we started the pdf scrapping with [tabula library](https://tabula-py.readthedocs.io/en/latest/) tabula is also [here](https://www.youtube.com/watch?v=tEFAFQXaOWw) but ended the job with [camelot library](https://camelot-py.readthedocs.io/en/master/) which we found more interesting for this task. We Used the [Selenium library](https://selenium-python.readthedocs.io/) for scraping the website
#
#
# _Process:_
#
# for each of the eleven urls of website pages with reports, we:
#  - had to uncomments the urls only one at a time to do the scrapping
#  - Scraped the page to obtain reports names, their link and other; this was done with selenium
#  - Using Tabula or Camelot we scraped each PDF file for demand and supply data; this was done by identifying the page corresponding to the targeted data, and scrapped a table to gather data corresponding only to Tamil Nadu.
#
#  _Result:_
#  - A 130 entries and 14 Columns dataset store in a .csv file
#
#  _Challenges:_
#
#  Due to the fact that all reports were not having the same exact formating, we were at many ocasions obliged to localise the targeted data by opening the website and a monthly report and confirm the exact location of the data to scrap.
#
# NB: This Notebook was produced within the context of The Omdena [Chennai Chapter project on Electricity Power Outage Analysis](https://github.com/OmdenaAI/chennai-india-power-outage)

# %% [markdown]
# ### 1. Scrapping the website to obtain reports

# %%
# ##   Installing useful Libraries


# ! pip install tabula-py
# ! pip install "camelot-py[base]"
# ! pip install ghostscript

# %%
# Importing useful Libraries
from selenium import webdriver
import pandas as pd
import tabula
import ghostscript
import _tkinter
import camelot
import time

# %%
# Building our empty dataset to append rows after scrapping 

df_ = pd.DataFrame(columns=['state', 'Requirement(MU/DAY)', 'Energy_met(MU/DAY)', 'Surplus(+)/Deficit(-)(MU/DAY)', 'Requirement(MU)',
 'Energy_met(MU)', 'Surplus(+)/Deficit(-)(MU)', '%Shortage(MU)', 'Requirement(MW)', 'Peak_Demand_Met5(MW)', 
 'Surplus(+)/Deficit(-)(MW)', '%Shortage(MW)', 'date_report', 'name_report'])

# %%
df_=pd.read_csv('loadschedding_TamilNadu.csv')

# %%
# Enumerating the target urls to be scraped one after the other by uncommenting them

# first url
url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2022-23/'
# second url
# url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2021-22/'
# third url
# url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2020-21/'
# fourth url
# url ='https://posoco.in/reports/monthly-reports/monthly-reports-2019-20/'
# fifth url
# url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2018-19/'
# sixth url
#url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2017-18/'
# seventh url
# url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2016-17/'
# eigth url
# url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2015-16/'
# ninth url
# url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2014-15/'
# tenth url
# url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2013-14/'
# eleventh url
# url = 'https://posoco.in/reports/monthly-reports/monthly-reports-2012-13/'

# %%
# setting the webdriver with Chrome
driver = webdriver.Chrome()

# %%
# Access the webpage
driver.get(url)

# %%
#Performing the Scrapping after analysis of the webpage format

from selenium.webdriver.common.by import By
classes = ['odd', 'even'] # the report are either from the 'odd' or 'even' classes
rows = []                  # a list to contain our results
for clas in classes:
    monthly_reports = driver.find_elements(By.CLASS_NAME, clas)                  
    for report in monthly_reports:
        date_report = report.find_elements(By.CLASS_NAME, 'hidden-xs')[1].text
        name_report = report.find_element(By.TAG_NAME,'a').text
        link_report = report.find_element(By.TAG_NAME, 'a').get_attribute('href')
        rows.append([date_report, name_report, link_report])

rows
# Out:
# [['23-04-2019',
#   'Monthly_Report_March_2019',
#   'https://posoco.in/download/monthly_report_march_2019/?wpdmdl=22786'],
#  ['22-02-2019',
#   'Monthly Report January 2019',
#   'https://posoco.in/download/monthly-report-january-2019/?wpdmdl=22031'],
#  ['21-12-2018',
#   'Monthly Report November 2018',
#   'https://posoco.in/download/monthly-report-november-2018/?wpdmdl=20943'],
#  ['23-10-2018',
#   'Monthly Report September 2018',
#   'https://posoco.in/download/monthly-report-september-2018/?wpdmdl=20135'],
#  ['23-08-2018',
#   'Monthly Report July 2018',
#   'https://posoco.in/download/monthly-report-july-2018/?wpdmdl=19263'],
#  ['22-06-2018',
#   'Monthly Report May 2018',
#   'https://posoco.in/download/monthly-report-may-2018/?wpdmdl=18367'],
#  ['22-03-2019',
#   'Monthly_report_February_2019',
#   'https://posoco.in/download/monthly_report_february_2019/?wpdmdl=22125'],
#  ['23-01-2019',
#   'Monthly Report December 2018',
#   'https://posoco.in/download/monthly-report-december-2018/?wpdmdl=21407'],
#  ['22-11-2018',
#   'Monthly Report October 2018',
#   'https://posoco.in/download/monthly-report-october-2018/?wpdmdl=20701'],
#  ['23-09-2018',
#   'Monthly Report August 2018',
#   'https://posoco.in/download/monthly-report-august-2018/?wpdmdl=19638'],
#  ['23-07-2018',
#   'Monthly Report June 2018',
#   'https://posoco.in/download/monthly-report-june-2018/?wpdmdl=18679'],
#  ['23-05-2018',
#   'Monthly Report April 2018',
#   'https://posoco.in/download/monthly-report-april-2018/?wpdmdl=17805']]

# %%
# our output in tabular format
df = pd.DataFrame(rows, columns=['date_report', 'name_report', 'link_report'])
df
# Out:
#    date_report                    name_report  \
# 0   23-04-2019      Monthly_Report_March_2019
# 1   22-02-2019    Monthly Report January 2019
# 2   21-12-2018   Monthly Report November 2018
# 3   23-10-2018  Monthly Report September 2018
# 4   23-08-2018       Monthly Report July 2018
# 5   22-06-2018        Monthly Report May 2018
# 6   22-03-2019   Monthly_report_February_2019
# 7   23-01-2019   Monthly Report December 2018
# 8   22-11-2018    Monthly Report October 2018
# 9   23-09-2018     Monthly Report August 2018
# 10  23-07-2018       Monthly Report June 2018
# 11  23-05-2018      Monthly Report April 2018
#
#                                           link_report
# 0   https://posoco.in/download/monthly_report_marc...
# 1   https://posoco.in/download/monthly-report-janu...
# 2   https://posoco.in/download/monthly-report-nove...
# 3   https://posoco.in/download/monthly-report-sept...
# 4   https://posoco.in/download/monthly-report-july...
# 5   https://posoco.in/download/monthly-report-may-...
# 6   https://posoco.in/download/monthly_report_febr...
# 7   https://posoco.in/download/monthly-report-dece...
# 8   https://posoco.in/download/monthly-report-octo...
# 9   https://posoco.in/download/monthly-report-augu...
# 10  https://posoco.in/download/monthly-report-june...
# 11  https://posoco.in/download/monthly-report-apri...

# %% [markdown]
# ### 2. Scrapping PDF files for demand and supply data

# %% [markdown]
# dfs = tabula.read_pdf(df.loc[1,'link_report'], lattice=True, pandas_options={"header": [0, 1]},  pages='29')
# #tabula.convert_into(df_22_23.loc[0,'link_report'], "output.csv", output_format="csv", pages='29')
# row = list(dfs[0].loc[27,1:]) + [df.iloc[1,0], df.iloc[1,1]]
# row_dict = {df_.columns[i]:row[i] for i in range(len(row))}
# df_ = df_.append(row_dict, ignore_index=True)

# %%
tables = camelot.read_pdf(df.loc[5,'link_report'], pages='28')

# %%
tables[0].df
# Out:
#                                              0          1                  2   \
# 0   11. ACTUAL POWER SUPPLY POSITION - May 2018
# 1                                                   REGION              STATE
# 2
# 3                                                       NR         Chandigarh
# 4                                                                       Delhi
# 5                                                                     Haryana
# 6                                                            Himachal Pradesh
# 7                                                                         J&K
# 8                                                                      Punjab
# 9                                                                   Rajasthan
# 10                                                              Uttar Pradesh
# 11                                                                Uttarakhand
# 12                                                                NFF/Railway
# 13                                                                      TOTAL
# 14                                                      WR            Gujarat
# 15                                                             Madhya Pradesh
# 16                                                               Chhattisgarh
# 17                                                                Maharashtra
# 18                                                                        Goa
# 19                                                                        D&D
# 20                                                                        DNH
# 21                                                                       ESIL
# 22                                                                      TOTAL
# 23                                                      SR     Andhra Pradesh
# 24                                                                  Telangana
# 25                                                                  Karnataka
# 26                                                                     Kerala
# 27                                                                 Tamil Nadu
# 28                                                                Pondicherry
# 29                                                                      TOTAL
# 30                                                      ER              Bihar
# 31                                                                  Jharkhand
# 32                                                                        DVC
# 33                                                                     Odisha
# 34                                                                West Bengal
# 35                                                                     Sikkim
# 36                                                                      TOTAL
# 37                                                     NER  Arunachal Pradesh
# 38                                                                      Assam
# 39                                                                    Manipur
# 40                                                                  Meghalaya
# 41                                                                    Mizoram
# 42                                                                   Nagaland
# 43                                                                    Tripura
# 44                                                                      TOTAL
# 45                                               ALL INDIA
# 46
#
#                                        3             4   \
# 0
# 1   Requirement/Availability  in \nMU/DAY
# 2                             Requirement  Energ\ny met
# 3                                     5.2           5.2
# 4                                   108.6         108.6
# 5                                   150.1         147.7
# 6                                    25.6          25.3
# 7                                    48.4          39.2
# 8                                   160.5         160.5
# 9                                   222.1         219.9
# 10                                  365.0         364.6
# 11                                   40.5          39.4
# 12                                    2.7           2.7
# 13                                 1128.7        1113.0
# 14                                  353.8         353.4
# 15                                  192.7         192.7
# 16                                   83.8          83.7
# 17                                  503.4         503.4
# 18                                   10.8          10.8
# 19                                    7.1           7.1
# 20                                   17.4          17.4
# 21                                    5.6           5.6
# 22                                 1174.4        1173.9
# 23                                  168.1         167.9
# 24                                  144.1         143.8
# 25                                  174.3         174.0
# 26                                   68.0          67.8
# 27                                  307.4         306.9
# 28                                    7.8           7.8
# 29                                  869.8         868.2
# 30                                   87.2          84.9
# 31                                   24.0          23.7
# 32                                   68.9          68.9
# 33                                   88.1          88.1
# 34                                  161.7         161.1
# 35                                    1.3           1.3
# 36                                  431.2         427.9
# 37                                    2.3           2.3
# 38                                   24.3          22.5
# 39                                    2.2           2.2
# 40                                    4.5           4.5
# 41                                    1.7           1.3
# 42                                    2.3           2.1
# 43                                    3.6           3.1
# 44                                   40.8          37.9
# 45                                 3644.9        3621.0
# 46
#
#                          5                                6             7   \
# 0
# 1                            Requirement/Availability  in MU
# 2   Surplus(+)/\nDeficit(-)                    Requirem\nent  Energy \nmet
# 3                       0.0                            161.5         161.5
# 4                       0.0                           3368.0        3366.8
# 5                      -2.4                           4652.2        4577.5
# 6                      -0.3                            793.8         783.5
# 7                      -9.2                           1500.2        1214.2
# 8                       0.0                           4974.4        4974.4
# 9                      -2.2                           6885.2        6817.9
# 10                     -0.4                          11316.0       11303.4
# 11                     -1.1                           1254.0        1220.8
# 12                      0.0                             84.0          84.0
# 13                    -15.7                          34989.3       34504.0
# 14                     -0.4                          10968.3       10955.5
# 15                      0.0                           5972.7        5972.7
# 16                     -0.1                           2596.3        2593.7
# 17                      0.0                          15605.4       15605.4
# 18                      0.0                            334.2         334.2
# 19                      0.0                            219.3         219.3
# 20                      0.0                            539.4         539.4
# 21                      0.0                            172.1         172.1
# 22                     -0.5                          36407.6       36392.2
# 23                     -0.2                           5212.5        5205.2
# 24                     -0.3                           4467.1        4459.3
# 25                     -0.3                           5403.4        5393.2
# 26                     -0.3                           2109.2        2101.4
# 27                     -0.5                           9528.5        9514.0
# 28                      0.0                            242.2         241.2
# 29                     -1.6                          26963.0       26914.3
# 30                     -2.3                           2704.1        2631.7
# 31                     -0.3                            743.6         733.6
# 32                      0.0                           2137.3        2137.3
# 33                      0.0                           2730.0        2730.0
# 34                     -0.7                           5013.3        4992.8
# 35                      0.0                             39.4          39.4
# 36                     -3.3                          13367.6       13264.7
# 37                      0.0                             70.9          70.8
# 38                     -1.8                            752.6         697.2
# 39                      0.0                             67.2          67.1
# 40                      0.0                            138.9         138.9
# 41                     -0.4                             51.2          39.9
# 42                     -0.2                             71.2          64.4
# 43                     -0.5                            112.5          96.3
# 44                     -2.9                             1264          1175
# 45                    -23.9                         112991.9      112249.8
# 46
#
#                          8             9                           10  \
# 0
# 1                                          Peak Demand/Peak Met in MW
# 2   Surplus(+)/\nDeficit(-)  % \nShortage                 Requirement
# 3                       0.0           0.0                         350
# 4                      -1.2           0.0                        6346
# 5                     -74.7          -1.6                        8351
# 6                     -10.3          -1.3                        1405
# 7                    -286.0         -19.1                        2945
# 8                       0.0           0.0                        8973
# 9                     -67.3          -1.0                       11298
# 10                    -12.6          -0.1                       19248
# 11                    -33.1          -2.6                        2097
# 12                      0.0           0.0                         103
# 13                   -485.4          -1.4                       56546
# 14                    -12.7          -0.1                       17157
# 15                      0.0           0.0                        9076
# 16                     -2.6          -0.1                        3890
# 17                      0.0           0.0                       23890
# 18                      0.0           0.0                         533
# 19                      0.0           0.0                         350
# 20                      0.0           0.0                         782
# 21                      0.0           0.0                         838
# 22                    -15.4           0.0                       54840
# 23                     -7.4          -0.1                        9264
# 24                     -7.8          -0.2                        7763
# 25                    -10.2          -0.2                        9778
# 26                     -7.8          -0.4                        4155
# 27                    -14.5          -0.2                       15192
# 28                     -1.0          -0.4                         396
# 29                    -48.7          -0.2                       43375
# 30                    -72.4          -2.7                        5008
# 31                    -10.0          -1.3                        1319
# 32                      0.0           0.0                        2916
# 33                      0.0           0.0                        4703
# 34                    -20.5          -0.4                        8731
# 35                      0.0           0.0                         104
# 36                   -102.9          -0.8                       21994
# 37                     -0.1          -0.1                         128
# 38                    -55.4          -7.4                        1621
# 39                     -0.1          -0.1                         179
# 40                      0.0           0.0                         368
# 41                    -11.3         -22.0                          96
# 42                     -6.8          -9.6                         147
# 43                    -16.3         -14.4                         276
# 44                    -89.8          -7.1                        2816
# 45                   -742.2          -0.7                      179571
# 46
#
#                      11                       12              13 14
# 0
# 1
# 2   Peak \nDemand \nMet  Surplus(+)/\nDeficit(-)  % \nShorta\nge
# 3                   350                        0             0.0
# 4                  6346                        0             0.0
# 5                  8351                        0             0.0
# 6                  1405                        0             0.0
# 7                  2356                     -589           -20.0
# 8                  8973                        0             0.0
# 9                 11298                        0             0.0
# 10                19248                        0             0.0
# 11                 2097                        0             0.0
# 12                  103                        0             0.0
# 13                56243                     -303            -0.5
# 14                16811                     -346            -2.0
# 15                 9058                      -19            -0.2
# 16                 3879                      -11            -0.3
# 17                23755                     -135            -0.6
# 18                  531                       -2            -0.4
# 19                  350                        0             0.0
# 20                  782                        0             0.0
# 21                  838                        0             0.0
# 22                54534                     -305            -0.6
# 23                 9249                      -15            -0.2
# 24                 7752                      -11            -0.1
# 25                 9778                        0             0.0
# 26                 4011                     -144            -3.5
# 27                15122                      -70            -0.5
# 28                  394                       -2            -0.5
# 29                43325                      -50            -0.1
# 30                 4824                     -184            -3.7
# 31                 1319                        0             0.0
# 32                 2916                        0             0.0
# 33                 4703                        0             0.0
# 34                 8731                        0             0.0
# 35                  104                        0             0.0
# 36                21994                        0             0.0
# 37                  123                       -5            -3.9
# 38                 1596                      -25            -1.5
# 39                  172                       -7            -3.9
# 40                  368                        0             0.0
# 41                   87                       -9            -9.4
# 42                  119                      -28           -19.1
# 43                  276                        0             0.0
# 44                 2742                      -74            -2.6
# 45               178838                     -732            -0.4
# 46

# %%
########################  With camelot Library  ######################f
for k in range(df.shape[0]):
    tables = camelot.read_pdf(df.loc[k,'link_report'], pages='21')
    row = list(tables[0].df.loc[27,2:13]) + [df.iloc[k,0], df.iloc[k,1]]
    print(row,len(row))
    row_dict = {df_.columns[i]:row[i] for i in range(len(row))}
    df_ = df_.append(row_dict, ignore_index=True)
# Out:
# ['TNEB', '303.1', '303.0', '-0.1', '9396.1', '9392.7', '-3.4', '0.0', '14613', '14584', '-29', '-0.2', '21-04-2017', 'Monthly Report March 2017'] 14
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# <ipython-input-88-a6c8a71f5a37> in <module>()
#       1 for k in range(df.shape[0]):
# ----> 2     tables = camelot.read_pdf(df.loc[k,'link_report'], pages='21')
#       3     row = list(tables[0].df.loc[27,2:13]) + [df.iloc[k,0], df.iloc[k,1]]
#       4     print(row,len(row))
#       5     row_dict = {df_.columns[i]:row[i] for i in range(len(row))}
#
# c:\Users\user\Anaconda3\lib\site-packages\camelot\io.py in read_pdf(filepath, pages, password, flavor, suppress_stdout, layout_kwargs, **kwargs)
#     109
#     110         validate_input(kwargs, flavor=flavor)
# --> 111         p = PDFHandler(filepath, pages=pages, password=password)
#     112         kwargs = remove_extra(kwargs, flavor=flavor)
#     113         tables = p.parse(
#
# c:\Users\user\Anaconda3\lib\site-packages\camelot\handlers.py in __init__(self, filepath, pages, password)
#      37     def __init__(self, filepath, pages="1", password=None):
#      38         if is_url(filepath):
# ---> 39             filepath = download_url(filepath)
#      40         self.filepath = filepath
#      41         if not filepath.lower().endswith(".pdf"):
#
# c:\Users\user\Anaconda3\lib\site-packages\camelot\utils.py in download_url(url)
#      88         if content_type != "application/pdf":
#      89             raise NotImplementedError("File format not supported")
# ---> 90         f.write(obj.read())
#      91     filepath = os.path.join(os.path.dirname(f.name), filename)
#      92     shutil.move(f.name, filepath)
#
# c:\Users\user\Anaconda3\lib\http\client.py in read(self, amt)
#     458             else:
#     459                 try:
# --> 460                     s = self._safe_read(self.length)
#     461                 except IncompleteRead:
#     462                     self._close_conn()
#
# c:\Users\user\Anaconda3\lib\http\client.py in _safe_read(self, amt)
#     610             chunk = self.fp.read(min(amt, MAXAMOUNT))
#     611             if not chunk:
# --> 612                 raise IncompleteRead(b''.join(s), amt)
#     613             s.append(chunk)
#     614             amt -= len(chunk)
#
# IncompleteRead: IncompleteRead(294060 bytes read, 2443544 more expected)

# %% [markdown]
# ## Particular cases done manually (converted to markdown to desactivate)
# #for  p,k in {'26' : 8 , '26' : 9 , '21' : 10, '21' : 11}.items():
# # [5,6,7,8,9,10,11 ]
# for k in [9,10,11 ]:
# # in range(3,12):
#     tables = camelot.read_pdf(df.loc[k,'link_report'], pages='28')
#     row = list(tables[0].df.loc[27,2:13]) + [df.iloc[k,0], df.iloc[k,1]]
#     print(row,len(row))
#     row_dict = {df_.columns[i]:row[i] for i in range(len(row))}
#     df_ = df_.append(row_dict, ignore_index=True)

# %% [markdown]
# l=[['Tamil Nadu', '318.3', '318.0', '-0.3', '9868.3', '9858.7', '-9.6', '-0.1', '15251', '15193', '-58', '-0.4', '23-04-2018', 'Monthly Report March 2018'],
# ['Tamil Nadu', '278.1', '277.9', '-0.2', '8620.9', '8613.9', '-6.9', '-0.1', '14406', '14373', '-33', '-0.2', '23-02-2018', 'Monthly Report January 2018'],
# ['TNEB', '269.5', '269.2', '-0.3', '8085.2', '8076.0', '-9.2', '-0.1', '14561', '14561', '0', '0.0', '22-12-2017', 'Monthly Report November 2017'] ]
#
# for row in l:
#     row_dict = {df_.columns[i]:row[i] for i in range(len(row))}
#     df_ = df_.append(row_dict, ignore_index=True)

# %% [markdown]
# l=[['TNEB', '257', '198', '-59', '7707', '5940', '-1767', '-23', '11661', '10078', '-1583', '-14', '21-07-2014', 'Monthly Report April 2012'] ]
#
# for row in l:
#     row_dict = {df_.columns[i]:row[i] for i in range(len(row))}
#     df_ = df_.append(row_dict, ignore_index=True)

# %%
########################  With tabula Library  ######################
for k in list(range(df.shape[0])):
#for k in [5,6,7,8,9,10,11]:
    # Extract dataframe
    dfs = tabula.read_pdf(df.loc[k,'link_report'], lattice=True, pandas_options={"header": [0, 1]},  pages='27')
    
    row = list(dfs[0].loc[28,2:13]) + [df.iloc[k,0], df.iloc[k,1]]
    print(row,len(row))
    row_dict = {df_.columns[i]:row[i] for i in range(len(row))}
    df_ = df_.append(row_dict, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     354                 try:
# --> 355                     return self._range.index(new_key)
#     356                 except ValueError as err:
#
# ValueError: 28 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-185-71bef0caa64c> in <module>()
#       6     dfs = tabula.read_pdf(df.loc[k,'link_report'], lattice=True, pandas_options={"header": [0, 1]},  pages='27')
#       7
# ----> 8     row = list(dfs[0].loc[28,2:13]) + [df.iloc[k,0], df.iloc[k,1]]
#       9     print(row,len(row))
#      10     row_dict = {df_.columns[i]:row[i] for i in range(len(row))}
#
# c:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# c:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# c:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     784                 # We don't need to check for tuples here because those are
#     785                 #  caught by the _is_nested_tuple_indexer check above.
# --> 786                 section = self._getitem_axis(key, axis=i)
#     787
#     788                 # We should never have a scalar section here, because
#
# c:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1108         # fall thru to straight lookup
#    1109         self._validate_key(key, axis)
# -> 1110         return self._get_label(key, axis=axis)
#    1111
#    1112     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# c:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#    1057     def _get_label(self, label, axis: int):
#    1058         # GH#5667 this will fail if the label is not present in the axis.
# -> 1059         return self.obj.xs(label, axis=axis)
#    1060
#    1061     def _handle_lowerdim_multi_index_axis0(self, tup: Tuple):
#
# c:\Users\user\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3491             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3492         else:
# -> 3493             loc = self.index.get_loc(key)
#    3494
#    3495             if isinstance(loc, np.ndarray):
#
# c:\Users\user\Anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     355                     return self._range.index(new_key)
#     356                 except ValueError as err:
# --> 357                     raise KeyError(key) from err
#     358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 28

# %%
df_
# Out:
#           state Requirement(MU/DAY) Energy_met(MU/DAY)  \
# 0    Tamil Nadu                 354                354
# 1    Tamil Nadu                 337                337
# 2    Tamil Nadu                 344                343
# 3    Tamil Nadu                 286                286
# 4    Tamil Nadu                 245                245
# ..          ...                 ...                ...
# 119        TNEB                 264                230
# 120        TNEB                 254                222
# 121        TNEB                1881               1977
# 122        TNEB                 257                198
# 123        TNEB                 257                198
#
#     Surplus(+)/Deficit(-)(MU/DAY) Requirement(MU) Energy_met(MU)  \
# 0                            -0.9           10632          10605
# 1                               0           10459          10458
# 2                            -0.3           10657          10648
# 3                               0            8873           8873
# 4                               0            7362           7360
# ..                            ...             ...            ...
# 119                           -35            7928           6893
# 120                           -32            7605           6649
# 121                            96              63             66
# 122                           -59            7707           5940
# 123                           -59            7707           5940
#
#     Surplus(+)/Deficit(-)(MU) %Shortage(MU) Requirement(MW)  \
# 0                         -26          -0.2           17646
# 1                          -1             0           16906
# 2                          -9          -0.1           17196
# 3                           1             0           15290
# 4                          -1             0           13501
# ..                        ...           ...             ...
# 119                     -1035           -13           12548
# 120                      -956           -13           10968
# 121                         3                    21-07-2014
# 122                     -1767           -23           11661
# 123                     -1767           -23           11661
#
#           Peak_Demand_Met5(MW) Surplus(+)/Deficit(-)(MW) %Shortage(MW)  \
# 0                        17563                       -83          -0.5
# 1                        16906                         0             0
# 2                        17196                         0             0
# 3                        15290                         0             0
# 4                        13480                       -21          -0.2
# ..                         ...                       ...           ...
# 119                      11283                     -1265           -10
# 120                      10491                      -477            -4
# 121  April 2012 Monthly Report                       NaN           NaN
# 122                      10078                     -1583           -14
# 123                      10078                     -1583           -14
#
#     date_report                name_report
# 0    23-05-2022    Monthly_Report_Apr_2022
# 1    23-06-2022    Monthly_Report_May_2022
# 2    25-04-2022    Monthly_Report_Mar_2022
# 3    23-02-2022    Monthly_Report_Jan_2022
# 4    23-12-2021    Monthly_Report_Nov_2021
# ..          ...                        ...
# 119  21-07-2014   June 2012 Monthly Report
# 120  21-07-2014    May 2012 Monthly Report
# 121         NaN                        NaN
# 122  21-07-2014  Monthly Report April 2012
# 123  21-07-2014  Monthly Report April 2012
#
# [124 rows x 14 columns]

# %%
df_.to_csv('loadschedding_TamilNadu.csv', index=False)

# %%
df_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          130 non-null    object
#  1   Requirement(MU/DAY)            130 non-null    object
#  2   Energy_met(MU/DAY)             130 non-null    object
#  3   Surplus(+)/Deficit(-)(MU/DAY)  130 non-null    object
#  4   Requirement(MU)                130 non-null    object
#  5   Energy_met(MU)                 130 non-null    object
#  6   Surplus(+)/Deficit(-)(MU)      130 non-null    object
#  7   %Shortage(MU)                  130 non-null    object
#  8   Requirement(MW)                130 non-null    object
#  9   Peak_Demand_Met5(MW)           130 non-null    object
#  10  Surplus(+)/Deficit(-)(MW)      130 non-null    object
#  11  %Shortage(MW)                  130 non-null    object
#  12  date_report                    130 non-null    object
#  13  name_report                    130 non-null    object
# dtypes: object(14)
# memory usage: 14.3+ KB
